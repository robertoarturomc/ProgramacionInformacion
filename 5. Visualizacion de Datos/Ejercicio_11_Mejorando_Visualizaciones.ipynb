# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Ejercicio 11: Mejorando las Visualizaciones
#
# Lee la siguiente celda para leer una archivo csv. Éste contiene información sobre el PIB *per capita* de una selección de países latinoamericanos.
#
# Contesta los ejercicios indicados y sube tu tarea en Brightspace.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/robertoarturomc/ProgramacionInformacion/main/5.%20Visualizacion%20de%20Datos/GDP_perCapita.csv")
df.head()
# Out:
#   Country Name         1960  ...          2019          2020
# 0    Argentina          NaN  ...   9912.281809   8441.919439
# 1      Bahamas  1550.267699  ...  34863.384050  28607.901380
# 2       Belice   304.903860  ...   5078.809944   4435.621154
# 3      Bolivia   102.237722  ...   3552.068144   3143.045494
# 4       Brasil   210.109873  ...   8897.487770   6796.844542
#
# [5 rows x 62 columns]

# %% [markdown]
# ### 1. La siguiente celda genera el código para crear un Gráfico de Líneas del PIB de El Salvador, de 2005 a la fecha.
# ### Modifica la celda para que el Gráfico incluya:
# 1. Un título apropiado.
# 2. Títulos apropiados en los ejes.

# %%
plt.plot(np.arange(2005, 2021),
         df.loc[df["Country Name"]=="El Salvador", "2005":].T)

plt.show()

# %% [markdown]
# ### 2. Crea un gráfico de Barras Horizontal con el PIB **ordenado** de Todos los países en 2020.
# ### ¡No olvides los títulos correspondientes!
#
# Tip: primero ordena la tabla, luego filtra para conservar sólo los datos del 2020 y finalmente crea el gráfico.

# %% [markdown]
# ### 3. A continuación, te comparto el código para crear una gráfica de puntos sobre los PIB históricos de México.
# ### a. Agrega, a ese mismo gráfico, el PIB histórico de Brasil y Chile.
# ### b. Agrega títulos.
# ### c. Agrega una leyenda.
# ### d. Investiga sobre los _markers_ en pyplot y ocupa uno distinto para cada país.

# %%
plt.scatter(np.arange(1960, 2021),
            df.loc[df["Country Name"]=="México", "1960":],
            marker="x")

plt.show()
